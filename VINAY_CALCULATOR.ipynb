# %% [markdown]
# <a href="https://colab.research.google.com/github/gopivinay499-jpg/calculator/blob/main/VINAY_CALCULATOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SUDIKONDA GOPI VENKATA VINAY**
#
# **CSE_AID**
#
# **25B25A4518**
#
# **CALCULATOR**

# %%
a=int(input("enter 1st number"))
b=int(input("enter 2nd number"))
op=input("enter operation")
def sum(a,b,op):
  if op ==  "+":
    print("addition of two numbers",a+b)
  elif op == "-":
    print("subtraction of two numbers",a-b)
  elif op == "*":
    print("multiplication of two numbers",a*b)
  elif op == "%":
    print("modulus of two numbers",a%b)
  elif op == "/":
    print("division of two numbers",a/b)
  else:
      print("invalid operation")
sum(a,b,op)
# Out:
# enter 1st number2
# enter 2nd number3
# enter operation*
# multiplication of two numbers 6
